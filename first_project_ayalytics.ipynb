# %% [markdown]
# # f(x) =0.6x^3+5.5x^2+10x -5
#
# 1. Определить корни
#
# 2. Найти интервалы, на которых функция возрастает
#
# 3. Найти интервалы, на которых функция убывает
#
# 4. Построить график
#
# 5. Вычислить вершину
#
# 6. Определить промежутки, на котором f > 0
#
# 7. Определить промежутки, на котором f < 0

# %% [markdown]
# ## Определение корней:

# %%
from sympy import Symbol, solve, diff

a  = 0.6
b = 5.5
c = 10
d = -5

x = Symbol("x")

f_x = a * (x**3) + b * (x**2) + c*(x**1)+d
f_x
print("корни:", solve(f_x,x))
# Out:
# корни: [-6.32174537314726 + 0.e-22*I, -3.25046383307744 - 0.e-22*I, 0.405542539558034 - 0.e-21*I]

# %% [markdown]
# ## График:

# %%
from sympy.plotting import plot

g1 = plot(f_x,(x,-7,5), line_color='red', title='график функции')

# %% [markdown]
# ## Нахождение производной:

# %%
derivative = diff(f_x)
derivative
# Out:
# 1.8*x**2 + 11.0*x + 10

# %%
g2 = plot(f_x, derivative,(x,-7,5), title="Совмещенный график", legend= True, xlabel='X', ylabel='Y', show=False)

g2[0].line_color = 'red'
g2[1].line_color = 'black'

g2.show()

# %% [markdown]
# ## Вершины функции:

# %%
print("корни производной:", solve(derivative,x))
print(f'вершины функции(точки локальных минимумов и максимумов): ({solve(derivative,x)[0].n(2)},0), ({solve(derivative,x)[1].n(2)},0)')
# Out:
# корни производной: [-5.00000000000000, -1.11111111111111]
# вершины функции(точки локальных минимумов и максимумов): (-5.0,0), (-1.1,0)

# %% [markdown]
# ## Функция возрастает:

# %%
solve(derivative > 0,x)
# Out:
# ((-1.11111111111111 < x) & (x < oo)) | ((-oo < x) & (x < -5.0))

# %% [markdown]
# ## Функция убывает:

# %%
 solve(derivative < 0,x)
# Out:
# (-5.0 < x) & (x < -1.11111111111111)

# %% [markdown]
# ## Производная второго порядка:

# %%
derivative_2 = diff(derivative)
derivative_2
# Out:
# 3.6*x + 11.0

# %%
g3 = plot(f_x, derivative, derivative_2, (x,-7,5), title="Совмещенный график", legend= True, xlabel='X', ylabel='Y', show=False)

g3[0].line_color = 'red'
g3[1].line_color = 'black'
g3[2].line_color = 'green'

g3.show()

# %% [markdown]
# ## Точка перегиба:

# %%
print("корень производной второго порядка:", solve(derivative_2,x)[0].n(2))
print(f'точка перегиба: ({solve(derivative_2,x)[0].n(2)}, 0)')
# Out:
# корень производной второго порядка: -3.1
# точка перегиба: (-3.1, 0)

# %% [markdown]
# ## f(x)>0

# %% [markdown]
# ## f(x)<0
